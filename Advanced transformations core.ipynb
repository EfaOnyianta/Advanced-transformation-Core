# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
hero_df = pd.read_csv("/Users/dell/Downloads/superhero_info - superhero_info.csv") 
hero_df
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
super_df = pd.read_csv("/Users/dell/Downloads/superhero_powers - superhero_powers.csv")
super_df
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]

# %%
hero_df['Hero|Publisher']. str.split('|', expand = True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
hero_df[['Hero Name', 'Publisher']] = hero_df['Hero|Publisher']. str.split('|', expand = True)
hero_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements      Hero Name  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
hero_df = hero_df.drop(columns = ['Hero|Publisher'])
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements      Hero Name  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
replace = ['{','}']
for char in replace:
    hero_df['Measurements']= hero_df['Measurements'].str.replace(char,'', regex = False)

# %%
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                  Measurements      Hero Name  \
# 0  'Height': '203.0 cm', 'Weight': '441.0 kg'         A-Bomb
# 1   'Height': '191.0 cm', 'Weight': '65.0 kg'     Abe Sapien
# 2   'Height': '185.0 cm', 'Weight': '90.0 kg'       Abin Sur
# 3  'Height': '203.0 cm', 'Weight': '441.0 kg'    Abomination
# 4  'Height': '193.0 cm', 'Weight': '122.0 kg'  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
height_weight = hero_df['Measurements'].apply(pd.Series)
height_weight
# Out:
#                                               0
# 0    'Height': '203.0 cm', 'Weight': '441.0 kg'
# 1     'Height': '191.0 cm', 'Weight': '65.0 kg'
# 2     'Height': '185.0 cm', 'Weight': '90.0 kg'
# 3    'Height': '203.0 cm', 'Weight': '441.0 kg'
# 4    'Height': '193.0 cm', 'Weight': '122.0 kg'
# ..                                          ...
# 458   'Height': '183.0 cm', 'Weight': '83.0 kg'
# 459   'Height': '165.0 cm', 'Weight': '52.0 kg'
# 460    'Height': '66.0 cm', 'Weight': '17.0 kg'
# 461   'Height': '170.0 cm', 'Weight': '57.0 kg'
# 462   'Height': '185.0 cm', 'Weight': '81.0 kg'
#
# [463 rows x 1 columns]

# %%
hero_df[['Height','Weight']] = hero_df['Measurements'].str.split(',', expand = True)
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                  Measurements      Hero Name  \
# 0  'Height': '203.0 cm', 'Weight': '441.0 kg'         A-Bomb
# 1   'Height': '191.0 cm', 'Weight': '65.0 kg'     Abe Sapien
# 2   'Height': '185.0 cm', 'Weight': '90.0 kg'       Abin Sur
# 3  'Height': '203.0 cm', 'Weight': '441.0 kg'    Abomination
# 4  'Height': '193.0 cm', 'Weight': '122.0 kg'  Absorbing Man
#
#            Publisher                Height                 Weight
# 0      Marvel Comics  'Height': '203.0 cm'   'Weight': '441.0 kg'
# ...

# %%
hero_df = hero_df.drop(columns = ['Measurements'])
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher                Height  \
# 0         A-Bomb      Marvel Comics  'Height': '203.0 cm'
# 1     Abe Sapien  Dark Horse Comics  'Height': '191.0 cm'
# 2       Abin Sur          DC Comics  'Height': '185.0 cm'
# 3    Abomination      Marvel Comics  'Height': '203.0 cm'
# 4  Absorbing Man      Marvel Comics  'Height': '193.0 cm'
#
#                   Weight
# 0   'Weight': '441.0 kg'
# 1    'Weight': '65.0 kg'
# 2    'Weight': '90.0 kg'
# 3   'Weight': '441.0 kg'
# 4   'Weight': '122.0 kg'

# %%
hero_df['Height'] = hero_df['Height'].astype(str).str.replace("[']", "", regex=True)

# %%
hero_df['Weight'] = hero_df['Weight'].astype(str).str.replace("[']", "", regex=True)

# %%
replace = [' ']
for char in replace:
    hero_df['Height']= hero_df['Height'].str.replace(char,'', regex = False)

# %%
hero_df['Height'].head()
# Out:
# 0    Height:203.0cm
# 1    Height:191.0cm
# 2    Height:185.0cm
# 3    Height:203.0cm
# 4    Height:193.0cm
# Name: Height, dtype: object

# %%
hero_df['Height'] = hero_df['Height'].str[7:]
hero_df['Height']= hero_df['Height'].str.replace('cm','', regex = False)

# %%
hero_df['Height'] = hero_df['Height'].astype(float)
hero_df['Height']
# Out:
# 0      203.0
# 1      191.0
# 2      185.0
# 3      203.0
# 4      193.0
#        ...
# 458    183.0
# 459    165.0
# 460     66.0
# 461    170.0
# 462    185.0
# Name: Height, Length: 463, dtype: float64

# %%
hero_df[['height1', 'Height(num)']] = hero_df['Height'].str.split(':', expand = True)
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher          Height             Weight  \
# 0         A-Bomb      Marvel Comics  Height:203.0cm   Weight: 441.0 kg
# 1     Abe Sapien  Dark Horse Comics  Height:191.0cm    Weight: 65.0 kg
# 2       Abin Sur          DC Comics  Height:185.0cm    Weight: 90.0 kg
# 3    Abomination      Marvel Comics  Height:203.0cm   Weight: 441.0 kg
# 4  Absorbing Man      Marvel Comics  Height:193.0cm   Weight: 122.0 kg
#
#   height1 Height(num)
# 0  Height     203.0cm
# 1  Height     191.0cm
# 2  Height     185.0cm
# 3  Height     203.0cm
# ...

# %%
hero_df = hero_df.drop(columns = ['height1', 'Height'])
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher             Weight Height(num)
# 0         A-Bomb      Marvel Comics   Weight: 441.0 kg     203.0cm
# 1     Abe Sapien  Dark Horse Comics    Weight: 65.0 kg     191.0cm
# 2       Abin Sur          DC Comics    Weight: 90.0 kg     185.0cm
# 3    Abomination      Marvel Comics   Weight: 441.0 kg     203.0cm
# 4  Absorbing Man      Marvel Comics   Weight: 122.0 kg     193.0cm

# %%
hero_df[['weight', 'Weight(num)']] = hero_df['Weight']. str.split(':', expand = True)
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher             Weight Height(num)   weight  \
# 0         A-Bomb      Marvel Comics   Weight: 441.0 kg     203.0cm   Weight
# 1     Abe Sapien  Dark Horse Comics    Weight: 65.0 kg     191.0cm   Weight
# 2       Abin Sur          DC Comics    Weight: 90.0 kg     185.0cm   Weight
# 3    Abomination      Marvel Comics   Weight: 441.0 kg     203.0cm   Weight
# 4  Absorbing Man      Marvel Comics   Weight: 122.0 kg     193.0cm   Weight
#
#   Weight(num)
# 0    441.0 kg
# 1     65.0 kg
# 2     90.0 kg
# 3    441.0 kg
# ...

# %%
hero_df = hero_df.drop(columns = ['weight', 'Weight'])
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher Height(num) Weight(num)
# 0         A-Bomb      Marvel Comics     203.0cm    441.0 kg
# 1     Abe Sapien  Dark Horse Comics     191.0cm     65.0 kg
# 2       Abin Sur          DC Comics     185.0cm     90.0 kg
# 3    Abomination      Marvel Comics     203.0cm    441.0 kg
# 4  Absorbing Man      Marvel Comics     193.0cm    122.0 kg

# %%
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher Height(num) Weight(num)
# 0         A-Bomb      Marvel Comics     203.0cm    441.0 kg
# 1     Abe Sapien  Dark Horse Comics     191.0cm     65.0 kg
# 2       Abin Sur          DC Comics     185.0cm     90.0 kg
# 3    Abomination      Marvel Comics     203.0cm    441.0 kg
# 4  Absorbing Man      Marvel Comics     193.0cm    122.0 kg

# %%
replace = [' ']
for char in replace:
    hero_df['Weight(num)']= hero_df['Weight(num)'].str.replace(char,'', regex = False)

# %%
hero_df['Weight(num)'].head()
# Out:
# 0    441.0kg
# 1     65.0kg
# 2     90.0kg
# 3    441.0kg
# 4    122.0kg
# Name: Weight(num), dtype: object

# %%
super_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
super_df = super_df.drop(columns = ['hero_names'])
super_df.head()
# Out:
#                                               Powers
# 0         Agility,Super Strength,Stamina,Super Speed
# 1  Accelerated Healing,Durability,Longevity,Super...
# 2  Agility,Accelerated Healing,Cold Resistance,Du...
# 3                                 Lantern Power Ring
# 4  Accelerated Healing,Intelligence,Super Strengt...

# %%
exploded = exploded(super_df.assign(Powers = super_df.Powers.str.split(",")), 'Powers')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 exploded = exploded(super_df.assign(Powers = super_df.Powers.str.split(",")), 'Powers')
#
# NameError: name 'exploded' is not defined

# %%
super_df.explode('Powers')
super_df
#exploded[['Powers']].head()
#exploded =

# %%
super_df['Powers'] = super_df['Powers'].str.split(",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 superhero_df['Powers'] = superhero_df['Powers'].str.split(",")
#
# NameError: name 'superhero_df' is not defined

# %%
superhero_df.head()

# %%
super_df['Powers'].value_counts

# %%
cols_to_make = exploded['Powers'].dropna().unique()
cols_to_make
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 cols_to_make = exploded['Powers'].dropna().unique()
#       2 cols_to_make
#
# NameError: name 'exploded' is not defined

# %%
for col in cols_to_make:
    superhero_df[col] = superhero_df['Powers'].str.contains(col)
superhero_df.head()

# %%
superhero_df

# %%
#Sherlins code 
#df = pd.merge(hero_df, powers_df, left_on='Hero', right_on ='hero_names')

# %%
superhero_df = pd.concat([hero_df, super_df], axis = 1, join = 'inner')
superhero_df.head()
