# %% [markdown]
# # ADVANCED TRANSFORMATIONS

# %% [markdown]
# #### Load libraries and dataframes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import warnings
warnings.filterwarnings(action ='ignore')

# %%
hero_df = pd.read_csv("/Users/dell/Downloads/superhero_info - superhero_info.csv") 
hero_df
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
super_df = pd.read_csv("/Users/dell/Downloads/superhero_powers - superhero_powers.csv")
super_df
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]

# %% [markdown]
# ## Cleaning Dataframe

# %%
hero_df['Hero|Publisher']. str.split('|', expand = True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %% [markdown]
# #### Split hero | publisher into 2 separate columns

# %%
hero_df[['Hero Name', 'Publisher']] = hero_df['Hero|Publisher']. str.split('|', expand = True)
hero_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements      Hero Name  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
#drop the original columan to avoid duplicated data
hero_df = hero_df.drop(columns = ['Hero|Publisher'])
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements      Hero Name  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
#getting rid of the brackets in the measurement column
replace = ['{','}']
for char in replace:
    hero_df['Measurements']= hero_df['Measurements'].str.replace(char,'', regex = False)

# %%
hero_df.head()
#check
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                  Measurements      Hero Name  \
# 0  'Height': '203.0 cm', 'Weight': '441.0 kg'         A-Bomb
# 1   'Height': '191.0 cm', 'Weight': '65.0 kg'     Abe Sapien
# 2   'Height': '185.0 cm', 'Weight': '90.0 kg'       Abin Sur
# 3  'Height': '203.0 cm', 'Weight': '441.0 kg'    Abomination
# 4  'Height': '193.0 cm', 'Weight': '122.0 kg'  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
height_weight = hero_df['Measurements'].apply(pd.Series)
height_weight
# Out:
#                                               0
# 0    'Height': '203.0 cm', 'Weight': '441.0 kg'
# 1     'Height': '191.0 cm', 'Weight': '65.0 kg'
# 2     'Height': '185.0 cm', 'Weight': '90.0 kg'
# 3    'Height': '203.0 cm', 'Weight': '441.0 kg'
# 4    'Height': '193.0 cm', 'Weight': '122.0 kg'
# ..                                          ...
# 458   'Height': '183.0 cm', 'Weight': '83.0 kg'
# 459   'Height': '165.0 cm', 'Weight': '52.0 kg'
# 460    'Height': '66.0 cm', 'Weight': '17.0 kg'
# 461   'Height': '170.0 cm', 'Weight': '57.0 kg'
# 462   'Height': '185.0 cm', 'Weight': '81.0 kg'
#
# [463 rows x 1 columns]

# %%
#split measurements into height/ weight. indicate to split on the , into 2 columns 
hero_df[['Height(cm)','Weight(kg)']] = hero_df['Measurements'].str.split(',', expand = True)
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                  Measurements      Hero Name  \
# 0  'Height': '203.0 cm', 'Weight': '441.0 kg'         A-Bomb
# 1   'Height': '191.0 cm', 'Weight': '65.0 kg'     Abe Sapien
# 2   'Height': '185.0 cm', 'Weight': '90.0 kg'       Abin Sur
# 3  'Height': '203.0 cm', 'Weight': '441.0 kg'    Abomination
# 4  'Height': '193.0 cm', 'Weight': '122.0 kg'  Absorbing Man
#
#            Publisher            Height(cm)             Weight(kg)
# 0      Marvel Comics  'Height': '203.0 cm'   'Weight': '441.0 kg'
# ...

# %%
hero_df = hero_df.drop(columns = ['Measurements'])
hero_df.head()
#drop measurements
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#        Hero Name          Publisher            Height(cm)  \
# 0         A-Bomb      Marvel Comics  'Height': '203.0 cm'
# 1     Abe Sapien  Dark Horse Comics  'Height': '191.0 cm'
# 2       Abin Sur          DC Comics  'Height': '185.0 cm'
# 3    Abomination      Marvel Comics  'Height': '203.0 cm'
# 4  Absorbing Man      Marvel Comics  'Height': '193.0 cm'
#
#               Weight(kg)
# 0   'Weight': '441.0 kg'
# 1    'Weight': '65.0 kg'
# 2    'Weight': '90.0 kg'
# 3   'Weight': '441.0 kg'
# 4   'Weight': '122.0 kg'

# %%
#get rid of square brackets for height and weight
hero_df['Height(cm)'] = hero_df['Height(cm)'].astype(str).str.replace("[']", "", regex=True)

# %%
hero_df['Weight(kg)'] = hero_df['Weight(kg)'].astype(str).str.replace("[']", "", regex=True)

# %%
#get rid of any random commas in the df
hero_df.columns = hero_df.columns.str.replace(' ', '')

# %%
hero_df['Height(cm)'].head()
# Out:
# 0    Height: 203.0 cm
# 1    Height: 191.0 cm
# 2    Height: 185.0 cm
# 3    Height: 203.0 cm
# 4    Height: 193.0 cm
# Name: Height(cm), dtype: object

# %%
#remove extra  words from both columns
hero_df['Height(cm)'] = hero_df['Height(cm)'].str[7:]
hero_df['Height(cm)']= hero_df['Height(cm)'].str.replace('cm','', regex = False)

# %%
hero_df['Height(cm)'] = hero_df['Height(cm)'].astype(float)
hero_df['Height(cm)']
# Out:
# 0      203.0
# 1      191.0
# 2      185.0
# 3      203.0
# 4      193.0
#        ...
# 458    183.0
# 459    165.0
# 460     66.0
# 461    170.0
# 462    185.0
# Name: Height(cm), Length: 463, dtype: float64

# %%
hero_df['Weight(kg)'] = hero_df['Weight(kg)'].str[8:]
hero_df['Weight(kg)']= hero_df['Weight(kg)'].str.replace('kg','', regex = False)

# %%
hero_df
# Out:
#      Gender               Race Alignment         Haircolor Eyecolor Skincolor  \
# 0      Male              Human      good           No Hair   yellow   Unknown
# 1      Male      Icthyo Sapien      good           No Hair     blue      blue
# 2      Male            Ungaran      good           No Hair     blue       red
# 3      Male  Human / Radiation       bad           No Hair    green   Unknown
# 4      Male              Human       bad           No Hair     blue   Unknown
# ..      ...                ...       ...               ...      ...       ...
# 458    Male              Human      good             Blond     blue   Unknown
# 459  Female              Human      good  Strawberry Blond     blue   Unknown
# 460    Male     Yoda's species      good             White    brown     green
# 461  Female              Human      good             Black     blue   Unknown
# 462    Male            Unknown       bad             Brown      red   Unknown
#
# ...

# %%
hero_df['Weight(kg)'] = hero_df['Weight(kg)'].astype(float)
hero_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Haircolor   463 non-null    object
#  4   Eyecolor    463 non-null    object
#  5   Skincolor   463 non-null    object
#  6   HeroName    463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height(cm)  463 non-null    float64
#  9   Weight(kg)  463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
hero_df.head()
# Out:
#   Gender               Race Alignment Haircolor Eyecolor Skincolor  \
# 0   Male              Human      good   No Hair   yellow   Unknown
# 1   Male      Icthyo Sapien      good   No Hair     blue      blue
# 2   Male            Ungaran      good   No Hair     blue       red
# 3   Male  Human / Radiation       bad   No Hair    green   Unknown
# 4   Male              Human       bad   No Hair     blue   Unknown
#
#         HeroName          Publisher  Height(cm)  Weight(kg)
# 0         A-Bomb      Marvel Comics       203.0       441.0
# 1     Abe Sapien  Dark Horse Comics       191.0        65.0
# 2       Abin Sur          DC Comics       185.0        90.0
# 3    Abomination      Marvel Comics       203.0       441.0
# 4  Absorbing Man      Marvel Comics       193.0       122.0

# %%
super_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
#Split powers to make it a string
super_df['Super_Powers'] = super_df['Powers'].str.split(",")
super_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Super_Powers
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
exploded = super_df.explode('Super_Powers')
exploded[['hero_names','Powers', 'Super_Powers']].head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Super_Powers
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
cols_to_make = exploded['Super_Powers'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
power = super_df.loc[0, "Powers"]
print(type(power))
power
# Out:
# <class 'str'>
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
super_df['Powers'].value_counts()
# Out:
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# Agility,Stealth,Marksmanship,Weapons Master,Stamina                                                                                                                                                                                                                  4
# ...

# %%
for col in cols_to_make:
    super_df[col] = super_df['Powers'].str.contains(col)
super_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Super_Powers  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# ...

# %%
super_df.drop(columns =['Powers','Super_Powers'])
# Out:
#           hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0            3-D Man     True            True     True         True
# 1             A-Bomb    False            True     True        False
# 2         Abe Sapien     True            True     True        False
# 3           Abin Sur    False           False    False        False
# 4        Abomination    False            True     True         True
# ..               ...      ...             ...      ...          ...
# 662  Yellowjacket II    False           False    False        False
# 663             Ymir    False            True    False        False
# 664             Yoda     True           False     True         True
# 665          Zatanna    False           False    False        False
# 666             Zoom    False           False    False         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# ...

# %%
superhero_df = pd.concat([hero_df, super_df], axis = 1, join = 'inner')
superhero_df.head()
# Out:
#   Gender               Race Alignment Haircolor Eyecolor Skincolor  \
# 0   Male              Human      good   No Hair   yellow   Unknown
# 1   Male      Icthyo Sapien      good   No Hair     blue      blue
# 2   Male            Ungaran      good   No Hair     blue       red
# 3   Male  Human / Radiation       bad   No Hair    green   Unknown
# 4   Male              Human       bad   No Hair     blue   Unknown
#
#         HeroName          Publisher  Height(cm)  Weight(kg)  ...  \
# 0         A-Bomb      Marvel Comics       203.0       441.0  ...
# 1     Abe Sapien  Dark Horse Comics       191.0        65.0  ...
# 2       Abin Sur          DC Comics       185.0        90.0  ...
# 3    Abomination      Marvel Comics       203.0       441.0  ...
# 4  Absorbing Man      Marvel Comics       193.0       122.0  ...
#
#   Weather Control Omnipresent Omniscient  Hair Manipulation  Nova Force  \
# 0           False       False      False              False       False
# ...

# %%
superhero_df.groupby(['Super Speed'])['Weight(kg)'].mean()
# Out:
# Super Speed
# False    113.705479
# True     113.391813
# Name: Weight(kg), dtype: float64

# %%
superhero_df.groupby(['Publisher'])['Height(cm)'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height(cm), dtype: float64
